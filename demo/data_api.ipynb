# %%
from deepclo.pipe.dataset import ImageDataProvider
from deepclo.core.measures.measure_functions import Measure

ds = ImageDataProvider(dataset_name='cifar10')

ds.input_shape
# Out:
# (32, 32, 3)

# %%
ds.plot_dataset_measure_distribution(measure=Measure.ENTROPY)

# %%
ds.plot_dataset_measure_distribution(measure=Measure.MI, limit=100, reference_block_index=0)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 ds.plot_dataset_measure_distribution(measure=Measure.MI, limit=100, reference_block_index=0)
#
# File C:\github\clo\deepclo\pipe\dataset.py:132, in ImageDataProvider.plot_dataset_measure_distribution(self, measure, limit, reference_block_index)
#     120 """
#     121 Plot distribution of content measure (similarity) of the dataset
#     122
#    (...)
#     129
#     130 """
#     131 data = {}
# --> 132 train_ranks = assess_and_rank_images(self.x_train[:limit],
#     133                                      content_measure=measure,
#     134                                      reference_block_index=reference_block_index)
#     136 val_ranks = assess_and_rank_images(self.x_test[:limit],
#     137                                    content_measure=measure,
# ...

# %%
ds = ImageDataProvider(dataset_name='cifar100')
ds.plot_dataset_measure_distribution(measure=Measure.ENTROPY, limit=1000)
